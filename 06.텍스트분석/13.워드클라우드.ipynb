# %% [markdown]
# ### 한글 워드클라우드
# - 한빛 아카데미 > 새로나온 책의 TAG 정보

# %% [markdown]
# 1. 크롤링

# %%
import requests
from urllib.parse import quote
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
base_url = 'https://www.hanbit.co.kr'
main_url = '/academy/books/new_book_list.html'

# %%
lines = []
for page in tqdm(range(1, 24)):               # 총 페이지가 23 페이지
    url = f'{base_url}{main_url}?page={page}'
    result = requests.get(url)
    soup = BeautifulSoup(result.text)
    lis = soup.select('li.sub_book_list')
    for li in lis:
        href = li.select_one('.pop_quick_bg')['onclick'][10:-1]
        res = requests.get(base_url + href)
        book_soup = BeautifulSoup(res.text)
        tags = book_soup.select('.tag_area > a')
        for a in tags:
            lines.append(a.get_text().strip())
# Out:
# 100%|██████████| 23/23 [04:25<00:00, 11.55s/it]

# %%
lines[:10]
# Out:
# ['매트랩',
#  'MATLAB',
#  '매트랩 프로그래밍',
#  '의학통계',
#  '논문',
#  '통계',
#  '분석',
#  '데이터분석',
#  'jamovi',
#  '메타분석']

# %%
len(lines)
# Out:
# 2662

# %% [markdown]
# ##### 2. 워드 클라우드 만들기

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# - 태그 리스트(lines)를 frequecy dictionary로 만들기

# %%
tag_set = set(lines)
len(tag_set)
# Out:
# 1425

# %%
tag_dict = {item: lines.count(item) for item in tag_set}
# tag_dict = {}
# for item in tag_set:
#    tag_dict[item] = lines.count(item)

# %%
count = 0
for key, val in tag_dict.items():
    print(key, ':', val)
    count += 1
    if count > 5:
        break
# Out:
#  : 1
# 유도기 : 1
# 서버 : 4
# 데이터 과학 : 12
# 수출 : 1
# 비주얼스튜디오2012 : 1

# %% [markdown]
# - 워드 클라우드

# %%
wc = WordCloud(
    background_color='white', random_state=2023
)
wc = wc.generate_from_frequencies(tag_dict)

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis('off');

# %%
wc = WordCloud(
    background_color='white', random_state=2023,
    font_path='c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tag_dict)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# - 태그 단어 리스트를 펼쳐서 문자열로 만든 후 워드 클라우드 만들기

# %%
tag_text = ' '.join(lines)
print(tag_text[:100])
# Out:
# 매트랩 MATLAB 매트랩 프로그래밍 의학통계 논문 통계 분석 데이터분석 jamovi 메타분석 패널데이터 의사 의학 보건 정보 교육 교과교육론 정보교과교육 SW교육 IT교육 회로

# %%
wc = WordCloud(
    background_color='white', random_state=2023,
    font_path='c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tag_text)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 wc = WordCloud(
#       2     background_color='white', random_state=2023,
#       3     font_path='c:/Windows/Fonts/malgun.ttf'
# ----> 4 ).generate_from_frequencies(tag_text)
#       6 plt.imshow(wc, interpolation='bilinear')
#       7 plt.axis('off');
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\wordcloud\wordcloud.py:408, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     392 """Create a word_cloud from words and frequencies.
#     393
#     394 Parameters
#    (...)
#     405
#     406 """
#     407 # make sure frequencies are sorted and normalized
# --> 408 frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409 if len(frequencies) <= 0:
#     410     raise ValueError("We need at least 1 word to plot a word cloud, "
#     411                      "got %d." % len(frequencies))
#
# AttributeError: 'str' object has no attribute 'items'
