# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('static/img/dead-lift.jpg')
plt.imshow(img), plt.axis('off');

# %%
np.array(img).shape
# Out:
# (168, 300, 3)

# %%
h, w, _ = np.array(img).shape

# %%
if h > w:
    width, height = w, w
else:
    width, height = h, h

# %%
diff = abs(h - w) // 2

# %%
if w > h:           # landscap image
    final_img = np.array(img)[:, diff:diff+h, :]
else:               # portrait image
    final_img = np.array(img)[diff:diff+w, :, :]

# %%
new_img = Image.fromarray(final_img)
plt.imshow(new_img), plt.axis('off');

# %%
import image_util as iu
plt.imshow(iu.center_image(img));

# %%
img.save('static/data/profile.png', format='png')

# %%
iu.center_image(img);
