# %% [markdown]
# ### Matplotlib 한글 사용 - VSCode

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.7.1'

# %% [markdown]
# - 라인 플롯

# %%
plt.plot([0,1,2,3], [0,1,4,9])      # X, Y
plt.title('Line plot')              # 제목
plt.grid()                          # 격자선
plt.show()

# %%
plt.plot([0,1,2,3], [0,1,4,9])      # X, Y
plt.title('라인 플롯')              # 제목
plt.grid()                          # 격자선
plt.show()
# Out:
# c:\Users\YONSAI\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YONSAI\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YONSAI\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YONSAI\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47215 (\N{HANGUL SYLLABLE ROS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - 가장 쉬운 방법

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.plot([0,1,2,3], [0,1,4,9])      # X, Y
plt.title('라인 플롯')              # 제목
plt.grid()                          # 격자선
plt.show()

# %% [markdown]
# - 다양한 폰트를 설정하는 방법

# %%
import matplotlib.font_manager as fm
path = 'C:/Users/YONSAI/AppData/Local/Microsoft/Windows/Fonts'
font_list = fm.findSystemFonts(fontpaths=path, fontext='ttf')

# %%
font_list[:10]
# Out:
# ['C:\\Users\\YONSAI\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-all.ttc']

# %%
f = fm.FontProperties(fname='C:\\Users\\YONSAI\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-all.ttc')
f.get_name()
# Out:
# 'D2Coding'

# %%
# [fm.FontProperties(fname=font).get_name() for font in font_list if 'Nanum' in font]
# Out:
# ['Nanum Pen Script']

# %%
fm.fontManager.addfont(path + '/D2Coding-Ver1.3.2-20180524-all.ttc')

# %%
plt.rcParams['font.family'] = 'D2Coding'
plt.plot([0,1,2,3], [0,1,4,9])      # X, Y
plt.title('라인 플롯 - D2Coding 폰트') 
plt.grid()                          # 격자선
plt.show()
