# %% [markdown]
# ### 서울시 공원 시각화

# %%
import numpy as np
import pandas as pd
import folium

# %%
df = pd.read_csv('data/서울시 주요 공원현황.csv', encoding='euc-kr')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   연번            132 non-null    int64
#  1   공원명           132 non-null    object
#  2   공원개요          131 non-null    object
#  3   면적            129 non-null    object
#  4   개원일           122 non-null    object
#  5   주요시설          124 non-null    object
#  6   주요식물          88 non-null     object
#  7   안내도           102 non-null    object
#  8   오시는길          115 non-null    object
#  9   이용시참고사항       120 non-null    object
#  10  이미지           132 non-null    object
#  11  지역            131 non-null    object
#  12  공원주소          132 non-null    object
#  13  관리부서          132 non-null    object
#  14  전화번호          132 non-null    object
#  15  X좌표(GRS80TM)  122 non-null    float64
#  16  Y좌표(GRS80TM)  122 non-null    float64
#  17  X좌표(WGS84)    131 non-null    float64
#  18  Y좌표(WGS84)    131 non-null    float64
#  19  바로가기          18 non-null     object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 20.8+ KB

# %%
df = df[['공원명', '면적', '공원주소', 'X좌표(WGS84)', 'Y좌표(WGS84)']]
df.columns = ['공원명', '면적', '주소', '경도', '위도']
df.head()
# Out:
#         공원명                                            면적
# 0  남산도시자연공원  2896887㎡ 임 야 : 2454140㎡ 녹지대 및 기타시설 : 442747㎡  \
# 1    길동생태공원                                        80683㎡
# 2     서울대공원                                     9132690m²
# 3       서울숲                                       480994㎡
# 4     월드컵공원                                      2284085㎡
#
#                              주소          경도         위도
# 0        서울특별시 중구 삼일대로 231(예장동)  126.990377  37.550140
# 1  서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779  37.540394
# 2            경기도 과천시 대공원광장로 102  127.019846  37.426449
# 3    서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798  37.543072
# 4     서울특별시 마포구 하늘공원로 84(월드컵공원)  126.878907  37.571805

# %%
df.dropna(subset=['면적', '경도'], inplace=True)
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# - 면적에 따라 공원크기를 지도에 표시

# %%
df.면적.head(30).tail(10)
# Out:
# 20      113021.7m2
# 21        201779㎥
# 22      258991㎡
# 23    10420819.08㎡
# 24       171294.1㎥
# 25        총 15000㎡
# 26         297926㎡
# 27         411972㎡
# 28          98470㎡
# 29      2038741.3㎡
# Name: 면적, dtype: object

# %%
df.drop([6], inplace=True)
df.head(10)
# Out:
#           공원명                                                 면적
# 0    남산도시자연공원       2896887㎡ 임 야 : 2454140㎡ 녹지대 및 기타시설 : 442747㎡  \
# 1      길동생태공원                                             80683㎡
# 2       서울대공원                                          9132690m²
# 3         서울숲                                            480994㎡
# 4       월드컵공원                                           2284085㎡
# 5   광화문시민열린마당                                            8948.1㎡
# 7     중마루근린공원                                              6456㎥
# 8        응봉공원  80309㎡ 배수지 시설용량 : 201.000㎥ 송수 펌프용량 : 직송급수계통 30...
# 9      매화근린공원                                         1980.4㎡
# 10     성수근린공원                                           5197.7㎡
#
#                               주소          경도         위도
# 0         서울특별시 중구 삼일대로 231(예장동)  126.990377  37.550140
# 1   서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779  37.540394
# 2             경기도 과천시 대공원광장로 102  127.019846  37.426449
# 3     서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798  37.543072
# 4      서울특별시 마포구 하늘공원로 84(월드컵공원)  126.878907  37.571805
# 5             서울특별시 종로구 세종로 76-2  126.978023  37.575045
# 7          서울특별시 영등포구 영등포동2가 222  126.911267  37.519832
# 8          서울특별시 성동구 금호동1가 산1-72  127.021765  37.557228
# 9           서울특별시 강서구 등촌동 630-14  126.861150  37.557583
# 10      서울특별시 성동구 성수2가 3동 302-25  127.052402  37.544814

# %%
# 시작할 때 있는 '총 ' 지우기
df.면적 = df.면적.str.replace('총 ', '')

# %%
# 앞에 있는 숫자만 추출하기 - 구분자㎡, m, ㎥
# 구분자가 여러개인 경우 split()
import re
re.split('[,.]', 'a,b.c')
# Out:
# ['a', 'b', 'c']

# %%
df.면적 = df.면적.apply(lambda x: re.split('[㎡m㎥]', x)[0])
df.면적.head()
# Out:
# 0    2896887
# 1      80683
# 2    9132690
# 3     480994
# 4    2284085
# Name: 면적, dtype: object

# %%
df.면적 = df.면적.astype(float).astype(int)
df.head()
# Out:
#         공원명       면적                            주소          경도         위도
# 0  남산도시자연공원  2896887        서울특별시 중구 삼일대로 231(예장동)  126.990377  37.550140
# 1    길동생태공원    80683  서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779  37.540394
# 2     서울대공원  9132690            경기도 과천시 대공원광장로 102  127.019846  37.426449
# 3       서울숲   480994    서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798  37.543072
# 4     월드컵공원  2284085     서울특별시 마포구 하늘공원로 84(월드컵공원)  126.878907  37.571805

# %% [markdown]
# - 공원 크기에 따라 분류

# %%
# 기준: 소형 < 100,000, 중형 < 1,000,000, 대형
criteria = [0, 100000, 1000000, 20000000]
labels = ['소형', '중형', '대형']       # 분류 기준
size_info = [3, 7, 15]                  # CircleMarker의 크기
df['분류'] = pd.cut(df.면적, criteria, labels=labels)
df['크기'] = pd.cut(df.면적, criteria, labels=size_info)
df.head()
# Out:
#         공원명       면적                            주소          경도         위도  분류
# 0  남산도시자연공원  2896887        서울특별시 중구 삼일대로 231(예장동)  126.990377  37.550140  대형  \
# 1    길동생태공원    80683  서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779  37.540394  소형
# 2     서울대공원  9132690            경기도 과천시 대공원광장로 102  127.019846  37.426449  대형
# 3       서울숲   480994    서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798  37.543072  중형
# 4     월드컵공원  2284085     서울특별시 마포구 하늘공원로 84(월드컵공원)  126.878907  37.571805  대형
#
#    크기
# 0  15
# 1   3
# 2  15
# 3   7
# 4  15

# %%
df.to_csv('data/서울공원요약.csv', index=False)

# %% [markdown]
# - 공원 시각화

# %%
park = folium.Map([37.55, 126.98], zoom_start=11)
for i in df.index:
    folium.CircleMarker(
        location=[df.위도[i], df.경도[i]],
        radius=int(df.크기[i]),             # int()를 할 것
        tooltip=df.공원명[i],
        popup=folium.Popup(df.주소[i], max_width=200),
        color='crimson', fill_color='crimson'
    ).add_to(park)

title_html = '<h3 align="center" style="font-size:20px">서울시 공원 현황</h3>'
park.get_root().html.add_child(folium.Element(title_html))
park
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa05e373dca782b4a90cd7bfb439c1cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;서울시 공원 현황&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa05e373dca782b4a90cd7bfb439c1cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa05e373dca782b4a90cd7bfb439c1cf = L.map(
#                 &quot;map_fa05e373dca782b4a90cd7bfb439c1cf&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_099e87a076d1c6d4436142226cda7b94 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa05e373dca782b4a90cd7bfb439c1cf);
#
#
#             var circle_marker_7f8e757940954ade4a87f528b74b7dfa = L.circleMarker(
#                 [37.5501402, 126.9903773],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa05e373dca782b4a90cd7bfb439c1cf);
#
#
#         var popup_c3fbacc8f98be75f9fb66933ba25f9a9 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_89a8b97a846cefa2a79e2c982de01b9e = $(`&lt;div id=&quot;html_89a8b97a846cefa2a79e2c982de01b9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 중구 삼일대로 231(예장동)&lt;/div&gt;`)[0];
#                 popup_c3fbacc8f98be75f9fb66933ba25f9a9.setContent(html_89a8b97a846cefa2a79e2c982de01b9e);
#
#
#
#         circle_marker_7f8e757940954ade4a87f528b74b7dfa.bindPopup(popup_c3fbacc8f98be75f9fb66933ba25f9a9)
#         ;
#
#
#
#
#             circle_marker_7f8e757940954ade4a87f528b74b7dfa.bindTooltip(
#                 `&lt;div&gt;
#                      남산도시자연공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f669af5f09a03840f94eedc7f690286b = L.circleMarker(
#                 [37.5403935, 127.1547791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa05e373dca782b4a90cd7bfb439c1cf);
#
#
#         var popup_779e185be34c147854306266e1fae28d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_aa146f4d345a0d285a91fe34ab63e010 = $(`&lt;div id=&quot;html_aa146f4d345a0d285a91fe34ab63e010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구 천호대로 1291(길동생태공원) &lt;/div&gt;`)[0];
#                 popup_779e185be34c147854306266e1fae28d.setContent(html_aa146f4d345a0d285a91fe34ab63e010);
#
#
#
#         circle_marker_f669af5f09a03840f94eedc7f690286b.bindPopup(popup_779e185be34c147854306266e1fae28d)
#         ;
#
#
#
#
#             circle_marker_f669af5f09a03840f94eedc7f690286b.bindTooltip(
#                 `&lt;div&gt;
#                      길동생태공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b1f63c90f2516e977f95550b1f54caec = L.circleMarker(
#                 [37.4264494, 127.0198465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa05e373dca782b4a90cd7bfb439c1cf);
#
#
#         var popup_d5f58356179881a6080ab5b1d1a0c0ee = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_292325b24f7d9df50b65a3f660d552b3 = $(`&lt;div id=&quot;html_292325b24f7d9df50b65a3f660d552b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 과천시 대공원광장로 102&lt;/div
