# %% [markdown]
# ### 8. 시계열 자료 다루기

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - DatetimeIndex

# %%
date_str = ['2023, 4, 17']
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2023-04-17'], dtype='datetime64[ns]', freq=None)

# %%
date_str = ['2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20', '2023-04-21']
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20',
#                '2023-04-21'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(np.random.randint(60, 100, 5),
                  columns=['score'], index=idx)
df
# Out:
#             score
# 2023-04-17     97
# 2023-04-18     71
# 2023-04-19     91
# 2023-04-20     76
# 2023-04-21     71

# %%
pd.date_range('2023-04-01', '2023-04-30')   # 시작일자, 종료일자
# Out:
# DatetimeIndex(['2023-04-01', '2023-04-02', '2023-04-03', '2023-04-04',
#                '2023-04-05', '2023-04-06', '2023-04-07', '2023-04-08',
#                '2023-04-09', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14', '2023-04-15', '2023-04-16',
#                '2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20',
#                '2023-04-21', '2023-04-22', '2023-04-23', '2023-04-24',
#                '2023-04-25', '2023-04-26', '2023-04-27', '2023-04-28',
#                '2023-04-29', '2023-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('4/1/23', periods=30)
# Out:
# DatetimeIndex(['2023-04-01', '2023-04-02', '2023-04-03', '2023-04-04',
#                '2023-04-05', '2023-04-06', '2023-04-07', '2023-04-08',
#                '2023-04-09', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14', '2023-04-15', '2023-04-16',
#                '2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20',
#                '2023-04-21', '2023-04-22', '2023-04-23', '2023-04-24',
#                '2023-04-25', '2023-04-26', '2023-04-27', '2023-04-28',
#                '2023-04-29', '2023-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('040123', '043023', freq='B')       # Biz day(주말을 제외한 평일)
# Out:
# DatetimeIndex(['2023-04-03', '2023-04-04', '2023-04-05', '2023-04-06',
#                '2023-04-07', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14', '2023-04-17', '2023-04-18',
#                '2023-04-19', '2023-04-20', '2023-04-21', '2023-04-24',
#                '2023-04-25', '2023-04-26', '2023-04-27', '2023-04-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
# 1년중 각 월의 주말이 아닌 시작일
pd.date_range('2023-1-1', '2023-12-31', freq='BMS')
# Out:
# DatetimeIndex(['2023-01-02', '2023-02-01', '2023-03-01', '2023-04-03',
#                '2023-05-01', '2023-06-01', '2023-07-03', '2023-08-01',
#                '2023-09-01', '2023-10-02', '2023-11-01', '2023-12-01'],
#               dtype='datetime64[ns]', freq='BMS')

# %% [markdown]
# - resample

# %%
ts = pd.DataFrame(np.random.randint(100, 1000, 100),
                  index=pd.date_range('20230101', periods=100))
ts.head()
# Out:
#               0
# 2023-01-01  303
# 2023-01-02  650
# 2023-01-03  793
# 2023-01-04  180
# 2023-01-05  755

# %%
ts.resample('M').first()
# Out:
#               0
# 2023-01-31  303
# 2023-02-28  979
# 2023-03-31  596
# 2023-04-30  932

# %%
ts.resample('W').first()    # 매주 일요일
# Out:
#               0
# 2023-01-01  303
# 2023-01-08  650
# 2023-01-15  413
# 2023-01-22  453
# 2023-01-29  565
# 2023-02-05  350
# 2023-02-12  396
# 2023-02-19  288
# 2023-02-26  236
# 2023-03-05  591
# 2023-03-12  124
# 2023-03-19  651
# 2023-03-26  442
# 2023-04-02  599
# 2023-04-09  994
# 2023-04-16  741

# %% [markdown]
# - 경기도 인구 소멸 비율(2022. 12 기준)
#     - 가임기 여성(만 20~39세) 인구수 / 60세 이상 노년 인구
#     - 경기도의 인구 소멸 위기지역 Top 10
#     - 위기지역: 기초자치단체 (시, 군)
#     - 특례시: 수원, 고양, 용인 (구)
#     - 행정구: 성남, 안산, 안양 (구)

# %%
d_pct = pd.read_csv('data/주민등록인구집계현황.csv', encoding='euc-kr')
d_pct.head(3)
# Out:
#      연도   월 행정구역구분명        행정구역명     총 인구수     0~9세   10~19세   20~29세
# 0  2022  12       도        경기도    13589432  1040954  1327726  1737291  \
# 1  2022  12      시군     경기도 가평군      62197     2930     4463     5929
# 2  2022  12     읍면동  경기도 가평군 가평읍     19555     1020     1673     2094
#
#     30~39세   40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)
# 0  1882300  2284603  ...      647283      821150      904073     1121889  \
# 1     5397     7589  ...        2186        2503        2433        3525
# 2     1795     2630  ...         778         937         848        1244
#
#    50~59세 (여)  60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  100세 이상 (여)
# 0     1133428      878494      437251      252711       44184         1369
# 1        5090        6439        3653        2408         411           13
# 2        1583        1805        1054         739         126            6
#
# [3 rows x 40 columns]

# %%
d_pct['인구 소멸 비율'] = (d_pct.loc[:, '20~29세 (여)':'30~39세 (여)'].sum(axis=1) / d_pct.loc[:, '60~69세':'100세 이상'].sum(axis=1)).round(2)
d_pct = d_pct[(d_pct['행정구역구분명'] != '도') & (d_pct['행정구역구분명'] != '읍면동')]
d_pct.head(3)
# Out:
#      연도   월 행정구역구분명         행정구역명    총 인구수   0~9세  10~19세  20~29세  30~39세
# 1  2022  12      시군      경기도 가평군     62197   2930    4463    5929    5397  \
# 8  2022  12      시군      경기도 고양시   1075202  73997  101074  140606  142572
# 9  2022  12       구  경기도 고양시 덕양구    487874  36231   41419   60469   70476
#
#    40~49세  ...  20~29세 (여)  30~39세 (여)  40~49세 (여)  50~59세 (여)  60~69세 (여)
# 1    7589  ...        2503        2433        3525        5090        6439  \
# 8  172996  ...       69028       71491       88876      101197       70061
# 9   78293  ...       29600       35039       38962       42695       32981
#
#    70~79세 (여)  80~89세 (여)  90~99세 (여)  100세 이상 (여)  인구 소멸 비율
# 1        3653        2408         411           13      0.20
# 8       35492       24019        4054          108      0.57
# 9       17538       11022        1750           44      0.56
#
# [3 rows x 41 columns]

# %%
d_pct = d_pct[['행정구역명', '인구 소멸 비율']]
d_pct
# Out:
#              행정구역명  인구 소멸 비율
# 1         경기도 가평군       0.20
# 8         경기도 고양시       0.57
# 9     경기도 고양시 덕양구       0.56
# 31   경기도 고양시 일산동구       0.60
# 44   경기도 고양시 일산서구       0.56
# 56        경기도 과천시       0.62
# 63        경기도 광명시       0.53
# 83        경기도 광주시       0.51
# 100       경기도 구리시       0.53
# 109       경기도 군포시       0.54
# 122       경기도 김포시       0.62
# 137      경기도 남양주시       0.51
# 156      경기도 동두천시       0.33
# 165       경기도 부천시       0.52
# 176       경기도 성남시       0.58
# 177   경기도 성남시 분당구       0.66
# 200   경기도 성남시 수정구       0.51
# 218   경기도 성남시 중원구       0.50
# 231       경기도 수원시       0.74
# 232   경기도 수원시 권선구       0.63
# 245   경기도 수원시 영통구       0.56
# 258   경기도 수원시 장안구       0.56
# 269   경기도 수원시 팔달구       0.53
# 280       경기도 시흥시       0.72
# 300       경기도 안산시       0.63
# 301   경기도 안산시 단원구       0.64
# 314   경기도 안산시 상록구       0.62
# 328       경기도 안성시       0.38
# 344       경기도 안양시       0.56
# 345   경기도 안양시 동안구       0.63
# 363   경기도 안양시 만안구       0.48
# 391       경기도 양평군       0.20
# 404       경기도 여주시       0.27
# 417       경기도 연천군       0.20
# 428       경기도 오산시       0.76
# 435       경기도 용인시       0.59
# 436   경기도 용인시 기흥구       0.61
# 452   경기도 용인시 수지구       0.66
# 464   경기도 용인시 처인구       0.48
# 477       경기도 의왕시       0.54
# 484      경기도 의정부시       0.53
# 499       경기도 이천시       0.51
# 514       경기도 파주시       0.56
# 532       경기도 평택시       0.65
# 558       경기도 포천시       0.28
# 574       경기도 하남시       0.67
# 589       경기도 화성시       0.87

# %%
d_pct = d_pct.drop([8, 176, 231, 300, 344, 435])
d_top10 = d_pct.sort_values(by=['인구 소멸 비율']).head(10)
d_top10
# Out:
#             행정구역명  인구 소멸 비율
# 1        경기도 가평군       0.20
# 391      경기도 양평군       0.20
# 417      경기도 연천군       0.20
# 404      경기도 여주시       0.27
# 558      경기도 포천시       0.28
# 156     경기도 동두천시       0.33
# 328      경기도 안성시       0.38
# 464  경기도 용인시 처인구       0.48
# 363  경기도 안양시 만안구       0.48
# 218  경기도 성남시 중원구       0.50
